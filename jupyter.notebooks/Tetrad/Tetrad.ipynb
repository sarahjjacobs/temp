# %% [markdown]
# ## Inferring the species tree with Tetrad - part of the distrubution of ipyrad
# ### this notebook follows the cookbook 'Inferring species trees with tetrad', at http://nbviewer.jupyter.org/github/dereneaton/ipyrad/blob/master/tests/cookbook-quartet-species-tree.ipynb

# %%
## If necessary, begin by installing ipyrad and toytree

# conda install ipyrad -c ipyrad
# conda install toytree -c eaton-lab

# %%
import ipyrad as ip
import ipyrad.analysis as ipa
import ipyparallel as ipp
import toytree

# %% [markdown]
# ## Connect to a cluster

# %%
ipyclient = ipp.Client()
print("connected to {} cores".format(len(ipyclient)))
# Out:
# connected to 10 cores
# /anaconda2/envs/py27/lib/python2.7/site-packages/ipyparallel/util.py:208: RuntimeWarning: IPython could not determine IPs for addr170.net185.lifesci.ucla.edu: [Errno 8] nodename nor servname provided, or not known
#   RuntimeWarning)
# /anaconda2/envs/py27/lib/python2.7/site-packages/ipyparallel/client/client.py:458: RuntimeWarning:
#             Controller appears to be listening on localhost, but not on this machine.
#             If this is true, you should specify Client(...,sshserver='you@addr170.net185.lifesci.ucla.edu')
#             or instruct your controller to listen on an external IP.
#   RuntimeWarning)

# %% [markdown]
# ## Run tetrad

# %%
## initiate a tetrad object
tet = ipa.tetrad(
    name='subset1.tetrad',
    data="/Users/sjjacobs/Desktop/data_to_mess_with/subset1_outfiles/subset1.snps.phy",
    mapfile="/Users/sjjacobs/Desktop/data_to_mess_with/subset1_outfiles/subset1.snps.map",
    nboots=1000,
    method="all",
    )
# Out:
# loading seq array [12 taxa x 34482 bp]
# max unlinked SNPs per quartet (nloci): 2816

# %% [markdown]
# ## Infer the tree

# %%
tet.run()
# Out:
# inferring 495 quartet tree sets
# host compute node: [10 cores] on addr170.net185.lifesci.ucla.edu
# [####################] 100% generating q-sets | 0:00:00 |
# [####################] 100% initial tree      | 0:00:00 |
# [####################] 100% bootstrap trees   | 0:05:22 |
# [####################] 100% calculating stats | 0:00:03 |

# %% [markdown]
# ## Draw the tree using toytree

# %%
## these are the newick tree files produced by the tetrad run
tet.trees
# Out:
# boots   ~/Desktop/jupyter.notebooks/Tetrad/analysis-tetrad/subset1.tetrad.boots
# cons    ~/Desktop/jupyter.notebooks/Tetrad/analysis-tetrad/subset1.tetrad.cons
# nhx     ~/Desktop/jupyter.notebooks/Tetrad/analysis-tetrad/subset1.tetrad.nhx
# tree    ~/Desktop/jupyter.notebooks/Tetrad/analysis-tetrad/subset1.tetrad.tree

# %%
## create a toytree object using the newick file path
tre = toytree.tree(tet.trees.nhx)

## draw unrooted consensus tree with support values
canvas, axes = tre.draw(
    width=300,
    node_labels=tre.get_node_values("support"),
    );

## draw unrooted consensus tree with the number of quartets 
## that can possibly be informative about any given split,
## given the 'true' tree
canvas, axes = tre.draw(
    width=300,
    node_labels=tre.get_node_values("quartets_total"),
    );
# Out:
# <div class="toyplot" id="t629014556a6c4c1cbac11415e3a462dd" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="275.0px" id="tc610a0e868cd4606b73f4e1d0fc40ce6" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 300.0 275.0" width="300.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t285792a83923486c84fd169b48a34b66"><clipPath id="t5ec00fe79fa54d5fac64d9d57dfc5c39"><rect height="225.0" width="250.0" x="25.0" y="25.0"></rect></clipPath><g clip-path="url(#t5ec00fe79fa54d5fac64d9d57dfc5c39)"><g class="toyplot-mark-Text" id="tc259237282944d448af4a1070cd4b3a6"><g class="toyplot-Series"><g class="toyplot-Datum" transform="translate(165.64058698254968,218.34741288278775)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">WP160_farinacea</text></g><g class="toyplot-Datum" transform="translate(165.64058698254968,203.64788326773544)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">WP152_farinacea</text></g><g class="toyplot-Datum" transform="translate(165.64058698254968,188.94835365268312)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">LF59_ledifolia</text></g><g class="toyplot-Datum" transform="translate(165.64058698254968,174.2488240376308)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">LF57_ledifolia</text></g><g class="toyplot-Datum" transform="translate(147.17696385088206,159.54929442257847)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">LF72_megapotamica</text></g><g class="toyplot-Datum" transform="translate(147.17696385088206,144.84976480752616)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">LF61_bifida</text></g><g class="toyplot-Datum" transform="translate(178.5975154960006,130.15023519247382)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">FZ266_paniculata</text></g><g class="toyplot-Datum" transform="translate(178.5975154960006,115.4507055774215)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">FZ271_paniculata</text></g><g class="toyplot-Datum" transform="translate(146.5291174252095,100.7511759623692)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">FZ200_paniculata</text></g><g class="toyplot-Datum" transform="translate(114.78464256725472,86.05164634731688)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" ...
# <div class="toyplot" id="t1b003fd0820e40188b564c60686fcd78" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="275.0px" id="t5c7af7eb5ab04ac99f1220c451b7e260" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 300.0 275.0" width="300.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tf83d097271ca48399ffdaf3080137702"><clipPath id="t6c6e41880267470da914d2dbfaa3d4cf"><rect height="225.0" width="250.0" x="25.0" y="25.0"></rect></clipPath><g clip-path="url(#t6c6e41880267470da914d2dbfaa3d4cf)"><g class="toyplot-mark-Text" id="t186d7323eec34961836d4630fc8ebdc9"><g class="toyplot-Series"><g class="toyplot-Datum" transform="translate(165.64058698254968,218.34741288278775)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">WP160_farinacea</text></g><g class="toyplot-Datum" transform="translate(165.64058698254968,203.64788326773544)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">WP152_farinacea</text></g><g class="toyplot-Datum" transform="translate(165.64058698254968,188.94835365268312)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">LF59_ledifolia</text></g><g class="toyplot-Datum" transform="translate(165.64058698254968,174.2488240376308)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">LF57_ledifolia</text></g><g class="toyplot-Datum" transform="translate(147.17696385088206,159.54929442257847)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">LF72_megapotamica</text></g><g class="toyplot-Datum" transform="translate(147.17696385088206,144.84976480752616)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">LF61_bifida</text></g><g class="toyplot-Datum" transform="translate(178.5975154960006,130.15023519247382)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">FZ266_paniculata</text></g><g class="toyplot-Datum" transform="translate(178.5975154960006,115.4507055774215)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">FZ271_paniculata</text></g><g class="toyplot-Datum" transform="translate(146.5291174252095,100.7511759623692)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" y="3.066">FZ200_paniculata</text></g><g class="toyplot-Datum" transform="translate(114.78464256725472,86.05164634731688)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;opacity:1.0;stroke:none;vertical-align:baseline;white-space:pre" x="15.0" ...

# %%
## save the tree figure in some format
import toyplot.svg
toyplot.svg.render(canvas, "analysis-tetrad/subset1.tetrad.tree.100boots.svg")

# %%
tet.params
# Out:
# method            all
# nboots            100
# nquartets         495
# resolve_ambigs    True
# save_invariants   False
