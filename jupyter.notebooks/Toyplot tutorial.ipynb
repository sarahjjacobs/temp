# %% [markdown]
# ### Toyplot tutorial - toyplot.readthedocs.io

# %%
import numpy
import toyplot

# %%
x = numpy.linspace(0, 10)
y = x ** 2

# %%
canvas = toyplot.Canvas(width=300, height=300)
axes = canvas.cartesian()
mark = axes.plot(x, y)
# Out:
# <div class="toyplot" id="tac433b1db6c74e9a9fd965ddb81e7123" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t7aeba8a415374b05a7523aa53703c1c5" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 300.0 300.0" width="300.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tee5ca7f167ad48998c241aeaa8715c18"><clipPath id="tc97891f4d4cd47a4b618a247efeb7e7e"><rect height="220.0" width="220.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#tc97891f4d4cd47a4b618a247efeb7e7e)"><g class="toyplot-mark-Plot" id="t2449d4ae75ef434db62ece3615207347" style="fill:none"><g class="toyplot-Series"><path d="M 50.0 250.0 L 54.08163265306122 249.916701374
# ...

# %% [markdown]
# ##### change the above line to be blue and dotted

# %%
canvas = toyplot.Canvas(width=300, height=300)
axes = canvas.cartesian()
mark = axes.plot(x, y, style={"stroke":"blue", "stroke-dasharray":"2,2"})
# Out:
# <div class="toyplot" id="ta733a124b30a48afbbca99b58bf5da35" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t1e777bbfb0b540e38c71bf322e7dde80" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 300.0 300.0" width="300.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tffb3a3acfc8a41189fe8cf994f8175c4"><clipPath id="te5bdaaaff1474582a2d5cc8c85b74b1c"><rect height="220.0" width="220.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#te5bdaaaff1474582a2d5cc8c85b74b1c)"><g class="toyplot-mark-Plot" id="t4f80c3db007c4e97bb800032db2ee7ca" style="fill:none;stroke:rgb(0%,0%,100%);stroke-dasharray:2,2;stroke-opacity:1.0"><g class="toyplot-
# ...

# %% [markdown]
# ##### you don't have to include the x coordinates

# %%
canvas = toyplot.Canvas(width=300, height=300)
axes = canvas.cartesian()
mark = axes.plot(y)
# Out:
# <div class="toyplot" id="te733df6f65604c04b699d28b04c287c9" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="td568406f5df94b54a549463fd00084e5" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 300.0 300.0" width="300.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tc895ba320b204b20b09072f45063357c"><clipPath id="ta2a3dcfcdf1541fc89629dbb9ee00c61"><rect height="220.0" width="220.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#ta2a3dcfcdf1541fc89629dbb9ee00c61)"><g class="toyplot-mark-Plot" id="tb20ab1c899ac4bb2a16866afb73b3783" style="fill:none"><g class="toyplot-Series"><path d="M 50.0 250.0 L 54.0 249.9167013744273 L 58.0 2
# ...

# %% [markdown]
# ##### if you add multiple plots to a set of axes, they are automatically assigned a new color

# %%
x = numpy.linspace(0, 10, 100)
y1 = numpy.sin(x)
y2 = numpy.cos(x)
y3 = numpy.sin(x) + numpy.cos(x)

# %%
canvas = toyplot.Canvas(width=600, height=300)
axes = canvas.cartesian()
mark1 = axes.plot(x, y1)
mark2 = axes.plot(x, y2)
mark3 = axes.plot(x, y3)
# Out:
# <div class="toyplot" id="t8b6d2ce8cf6a478c936668c5a64357b2" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t5dec194c8c8f483392fe25c3d0dfced4" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 300.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t5e5ee039d48c43d6803b27cd88e9293a"><clipPath id="t29670d83e8f343f1848757482b3abe27"><rect height="220.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t29670d83e8f343f1848757482b3abe27)"><g class="toyplot-mark-Plot" id="t6de0bd4fa23b41859995b65b7be9a9a3" style="fill:none"><g class="toyplot-Series"><path d="M 50.0 150.0037332927238 L 55.05050505050505 1
# ...

# %% [markdown]
# ##### here are some additional style options to chose from:

# %%
canvas = toyplot.Canvas(width=600, height=300)
axes = canvas.cartesian()
mark1 = axes.plot(x, y1, style={"stroke-width":1, "stroke-opacity":0.6})
mark2 = axes.plot(x, y2, style={"stroke-width":1, "stroke-opacity":0.6})
mark3 = axes.plot(x, y3, style={"stroke":"orange"})
# Out:
# <div class="toyplot" id="t53117e7a53424ba49ec94706f92ec9ab" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t5bb6d9ae9f1143a6a48dfe0b42854097" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 300.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="te23ee6bf62d2484cb075a3cc6ef5d272"><clipPath id="t3d3f96ab5cf24752ad94c3d5f1268bb9"><rect height="220.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t3d3f96ab5cf24752ad94c3d5f1268bb9)"><g class="toyplot-mark-Plot" id="tc890a082372849c3a5ea61e71f209a8b" style="fill:none;stroke-opacity:0.6;stroke-width:1"><g class="toyplot-Series"><path d="M 50.0 150.0
# ...

# %%
import toyplot.color
toyplot.color.Palette()
# Out:
# <div class="toyplot-color-Palette" style="overflow:hidden; height:auto"><div style="float:left;width:20px;height:20px;margin-right:0px;background-color:rgba(40.0%,76.1%,64.7%,1.000)"></div><div style="float:left;width:20px;height:20px;margin-right:0px;background-color:rgba(98.8%,55.3%,38.4%,1.000)"></div><div style="float:left;width:20px;height:20px;margin-right:0px;background-color:rgba(55.3%,62.7%,79.6%,1.000)"></div><div style="float:left;width:20px;height:20px;margin-right:0px;background-color:rgba(90.6%,54.1%,76.5%,1.000)"></div><div style="float:left;width:20px;height:20px;margin-right:0px;background-color:rgba(65.1%,84.7%,32.9%,1.000)"></div><div style="float:left;width:20px;height:20px;margin-right:0px;background-color:rgba(100.0%,85.1%,18.4%,1.000)"></div><div style="float:left;width:20px;height:20px;margin-right:0px;background-color:rgba(89.8%,76.9%,58.0%,1.000)"></div><div style="float:left;width:20px;height:20px;margin-right:0px;background-color:rgba(70.2%,70.2%,70.2%,1.0
# ...
